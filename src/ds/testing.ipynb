# %%
x = []

# %%
list(zip(*x))
# Out:
# []

# %%
x ='eashan'

# %%
x[1]
# Out:
# 'a'

# %%
x = [1, 2, 3, 4]

# %%
list(zip(x, x[1:]))
# Out:
# [(1, 2), (2, 3), (3, 4)]

# %%
strs = ['all', 'tall', 'alf']
selected_string = min(strs, key=len)

# %%
'a' in selected_string[0]
# Out:
# True

# %%
x = None
if not x:
    print('y')
# Out:
# y

# %%
if not None:
    print("Truthy")
# Out:
# Truthy
